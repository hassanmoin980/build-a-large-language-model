# %% [markdown]
# # **Chapter 02 - Summary**
#
# 1. Clean and normalize text to remove noise and standardize format.
# 2. Split text into word or subword tokens for efficient processing.
# 3. Apply *Byte Pair Encoding (BPE)* to build a compact subword vocabulary.
# 4. Use a sliding window to sample overlapping training sequences.
# 5. Convert tokens into dense vector embeddings for model input.

# %%
a = 1
